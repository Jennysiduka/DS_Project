# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

#Load Date
women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
#Set line color of women and men
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
#Only display stem majors
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

#Create figure
fig = plt.figure(figsize=(18, 3))

#for loop to create line comparison for each major
for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom=0, top=0, left=0, right=0)
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %% [markdown]
# #Comparing Women & Men across all majors

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
fig = plt.figure(figsize=(16,20))
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
#Stem Majors
for sp in range(0,18,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj= int(sp/3)
    ax.plot(women_degrees['Year'],women_degrees[stem_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth = 3)
    ax.plot(women_degrees['Year'],100-women_degrees[stem_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(stem_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0)
    if sp_maj == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    if sp_maj == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
        
#literature Majors
for sp in range(1,16,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj= int((sp-1)/3)
    ax.plot(women_degrees['Year'],women_degrees[lib_arts_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth = 3)
    ax.plot(women_degrees['Year'],100-women_degrees[lib_arts_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(lib_arts_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0)
    if sp_maj == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')



#Other Majors:
for sp in range(2,18,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj = int((sp-2)/3)
    ax.plot(women_degrees['Year'],women_degrees[other_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees['Year'],100-women_degrees[other_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(other_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0)
    if sp_maj== 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp_maj ==5:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')

# %%
#Remove the xtick of all chart except the bottom chart of each column
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
fig = plt.figure(figsize=(16,20))
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
#Stem Majors
for sp in range(0,18,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj= int(sp/3)
    ax.plot(women_degrees['Year'],women_degrees[stem_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth = 3)
    ax.plot(women_degrees['Year'],100-women_degrees[stem_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(stem_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0,labelbottom =0)
    if sp_maj == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    if sp_maj == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
        ax.tick_params(labelbottom = 1)
        
#literature Majors
for sp in range(1,16,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj= int((sp-1)/3)
    ax.plot(women_degrees['Year'],women_degrees[lib_arts_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth = 3)
    ax.plot(women_degrees['Year'],100-women_degrees[lib_arts_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(lib_arts_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0,labelbottom =0)
    if sp_maj == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    if sp_maj==4:
        ax.tick_params(labelbottom = 1)
        


#Other Majors:
for sp in range(2,18,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj = int((sp-2)/3)
    ax.plot(women_degrees['Year'],women_degrees[other_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees['Year'],100-women_degrees[other_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(other_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0,labelbottom = 0)
    if sp_maj== 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp_maj ==5:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
        ax.tick_params(labelbottom = 1)

# %%
#only retain y-axis lable 0 & 100
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
fig = plt.figure(figsize=(16,20))
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
#Stem Majors
for sp in range(0,18,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj= int(sp/3)
    ax.plot(women_degrees['Year'],women_degrees[stem_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth = 3)
    ax.plot(women_degrees['Year'],100-women_degrees[stem_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(stem_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0,labelbottom =0)
    if sp_maj == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    if sp_maj == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
        ax.tick_params(labelbottom = 1)
        
#literature Majors
for sp in range(1,16,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj= int((sp-1)/3)
    ax.plot(women_degrees['Year'],women_degrees[lib_arts_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth = 3)
    ax.plot(women_degrees['Year'],100-women_degrees[lib_arts_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(lib_arts_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0,labelbottom =0)
    if sp_maj == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    if sp_maj==4:
        ax.tick_params(labelbottom = 1)
        


#Other Majors:
for sp in range(2,18,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj = int((sp-2)/3)
    ax.plot(women_degrees['Year'],women_degrees[other_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees['Year'],100-women_degrees[other_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(other_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0,labelbottom = 0)
    if sp_maj== 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp_maj ==5:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
        ax.tick_params(labelbottom = 1)

# %%
#add horizontal line at y-axis 50 position
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
fig = plt.figure(figsize=(16,20))
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
#Stem Majors
for sp in range(0,18,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj= int(sp/3)
    ax.plot(women_degrees['Year'],women_degrees[stem_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth = 3)
    ax.plot(women_degrees['Year'],100-women_degrees[stem_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.axhline(50,c=(171/255,171/255,171/255),alpha=0.3)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(stem_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0,labelbottom =0)
    if sp_maj == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    if sp_maj == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
        ax.tick_params(labelbottom = 1)
        
#literature Majors
for sp in range(1,16,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj= int((sp-1)/3)
    ax.plot(women_degrees['Year'],women_degrees[lib_arts_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth = 3)
    ax.plot(women_degrees['Year'],100-women_degrees[lib_arts_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.axhline(50,c=(171/255,171/255,171/255),alpha=0.3)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(lib_arts_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0,labelbottom =0)
    if sp_maj == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    if sp_maj==4:
        ax.tick_params(labelbottom = 1)
        


#Other Majors:
for sp in range(2,18,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj = int((sp-2)/3)
    ax.plot(women_degrees['Year'],women_degrees[other_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees['Year'],100-women_degrees[other_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(other_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0,labelbottom = 0)
    ax.axhline(50,c=(171/255,171/255,171/255),alpha=0.3)
    if sp_maj== 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp_maj ==5:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
        ax.tick_params(labelbottom = 1)

# %%
plt.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
#save to folder
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
fig = plt.figure(figsize=(16,20))
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
#Stem Majors
for sp in range(0,18,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj= int(sp/3)
    ax.plot(women_degrees['Year'],women_degrees[stem_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth = 3)
    ax.plot(women_degrees['Year'],100-women_degrees[stem_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.axhline(50,c=(171/255,171/255,171/255),alpha=0.3)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(stem_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0,labelbottom =0)
    if sp_maj == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    if sp_maj == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
        ax.tick_params(labelbottom = 1)
        
#literature Majors
for sp in range(1,16,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj= int((sp-1)/3)
    ax.plot(women_degrees['Year'],women_degrees[lib_arts_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth = 3)
    ax.plot(women_degrees['Year'],100-women_degrees[lib_arts_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.axhline(50,c=(171/255,171/255,171/255),alpha=0.3)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(lib_arts_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0,labelbottom =0)
    if sp_maj == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    if sp_maj==4:
        ax.tick_params(labelbottom = 1)
        


#Other Majors:
for sp in range(2,18,3):
    ax = fig.add_subplot(6,3,sp+1)
    sp_maj = int((sp-2)/3)
    ax.plot(women_degrees['Year'],women_degrees[other_cats[sp_maj]], label='Women',c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees['Year'],100-women_degrees[other_cats[sp_maj]], label='Men',c=cb_orange,linewidth=3)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_title(other_cats[sp_maj])
    ax.tick_params(top=0,bottom=0,right=0,left=0,labelbottom = 0)
    ax.axhline(50,c=(171/255,171/255,171/255),alpha=0.3)
    if sp_maj== 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp_maj ==5:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
        ax.tick_params(labelbottom = 1)

plt.savefig('/gender_degree.pdf')
plt.show()
